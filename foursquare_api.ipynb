# %%
import json
import requests

# Load secrets from credentials.json
url = 'https://api.foursquare.com/v2/venues/explore'
with open('.secrets/credentials.json') as f:
    params = json.load(f)

# %%
params['v'] = '20180323'
params['ll'] = '47.608,-122.336',
params['query'] = 'yoga',
params['intent'] = 'browse',
params['radius'] = 100000,
params['limit'] = 100

# %%
response = requests.get(url=url, params=params)
data = json.loads(response.text)

# %%
data.keys()
# Out:
# dict_keys(['meta', 'response'])

# %%
data['response'].keys()
# Out:
# dict_keys(['suggestedFilters', 'headerLocation', 'headerFullLocation', 'headerLocationGranularity', 'query', 'totalResults', 'suggestedBounds', 'groups'])

# %%
data['meta']
# Out:
# {'code': 200, 'requestId': '5cf69d4f4434b92141e02896'}

# %%
type(data['response'])
# Out:
# dict

# %%
len(venues)
# Out:
# 100

# %%
venue_names
# Out:
# ['Urban Yoga Spa',
#  'Be Luminous Yoga',
#  'Haute Yoga',
#  'Seattle Yoga Arts',
#  'Seattle Bouldering Project',
#  'CorePower Yoga',
#  'CorePower Yoga',
#  '8 Limbs Yoga',
#  'The Grinning Yogi',
#  'Fusion Hot Yoga',
#  'Bala Yoga',
#  'Yogalife Queen Anne',
#  'Shefayoga',
#  'Shakti Vinyasa Yoga',
#  'Modo Yoga',
#  'Bindi Yoga',
#  'Shakti Vinyasa Yoga',
#  'Yogabliss',
#  'ProSports Club Spa',
#  'Live Love Flow',
#  'CorePower Yoga',
#  'Sweat Box Yoga',
#  'Get Zen Hot Yoga',
#  'CorePower Yoga',
#  'Bikram Yoga',
#  'Crunch - Bellevue',
#  'Bellevue Club',
#  'CorePower Yoga',
#  'Foundation CrossFit',
#  'TRIBE Fitness',
#  'Hot Yoga Inc.',
#  'Bikram Hot Yoga U-District',
#  'Hot Yoga at Mill Creek Town Center',
#  'The Ashram Yoga',
#  'CorePower Yoga',
#  'Aditi Yoga',
#  'YMCA',
#  'Denali Fitness',
#  'Olympic Athletic Club',
#  'Seattle Athletic Club',
#  'Samadhi Yoga',
#  'Pro Sports Club',
#  'Ballard Health Club',
#  'Breathe Hot Yoga',
#  'Bikram Yoga West Seattle',
#  'The Seattle Gym',
#  'Hot Yoga Experience',
#  'Pure 8 Hot Yoga Studio',
#  'Fitness Evolution',
#  'Hot Yoga Inc. - Covington',
#  "Gold's Gym",
#  'YMCA',
#  'Belltown Dance Studio',
#  'Ripple Yoga',
#  'barre3 Bellevue',
#  'iLovekickboxing.com - Kirkland',
#  'YMCA',
#  'Emerald City Athletics',
#  '24 Hour Fitness',
#  'Dale Turner Family YMCA',
#  'Banya 5',
#  'OmCulture',
#  'Island Fitness',
#  'Denali Fitness - Interbay',
#  "Gold's Gym",
#  'Elaia Spa',
#  'YMCA',
#  'Be One Yoga',
#  'Métier',
#  'Velocity Dance Center',
#  'Boeing, 40-201, Activity Center',
#  "Gold's Gym",
#  'Hot Yoga of Mill Creek',
#  'Soul Fitness Club',
#  'LA Fitness',
#  'DoubleTree by Hilton Fitness Center',
#  'Vertical World Everett',
#  '24 Hour Fitness',
#  'Bikram Yoga Seattle',
#  'LA Fitness',
#  'Ritual House',
#  'The Samarya Center',
#  'Seattle Executive Fitness',
#  'LA Fitness',
#  'The Yoga Den',
#  "Soldier's Field House",
#  'Village Green Yoga & Eco-Boutique',
#  'Home Yoga',
#  'Seattle Holistic Center',
#  'UniverseCity Yoga',
#  'Sutra Yoga',
#  'Community Fitness',
#  'Aum Yoga Therapy',
#  'Aspira Yoga Studio',
#  'Levitas Studio',
#  'Taj Yoga',
#  'Breathe Hot Yoga',
#  "Troy Lucero's Acme Yoga Project",
#  'Shanogi Yoga',
#  'Eka Yoga']

# %%
venues
# Out:
# [{'id': '4a823b1cf964a520f4f81fe3',
#   'name': 'Urban Yoga Spa',
#   'contact': {},
#   'location': {'address': '1900 4th Ave',
#    'crossStreet': 'at Stewart St',
#    'lat': 47.6125202562606,
#    'lng': -122.33867036193942,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.6125202562606,
#      'lng': -122.33867036193942}],
#    'distance': 541,
#    'postalCode': '98101',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['1900 4th Ave (at Stewart St)',
#     'Seattle, WA 98101',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4b08b44ef964a520161123e3',
#   'name': 'Be Luminous Yoga',
#   'contact': {},
#   'location': {'address': '900 Lenora St Ste 128',
#    'crossStreet': 'btw 9th and Terry',
#    'lat': 47.61794382708119,
#    'lng': -122.33786703766124,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.61794382708119,
#      'lng': -122.33786703766124}],
#    'distance': 1115,
#    'postalCode': '98121',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['900 Lenora St Ste 128 (btw 9th and Terry)',
#     'Seattle, WA 98121',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4a8e262df964a5201d1220e3',
#   'name': 'Haute Yoga',
#   'contact': {},
#   'location': {'address': '2131 Queen Anne Ave N',
#    'crossStreet': 'at Boston St',
#    'lat': 47.638106474620315,
#    'lng': -122.35702394020903,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.638106474620315,
#      'lng': -122.35702394020903}],
#    'distance': 3704,
#    'postalCode': '98109',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['2131 Queen Anne Ave N (at Boston St)',
#     'Seattle, WA 98109',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4be7229a334fb7131ae8a0bc',
#   'name': 'Seattle Yoga Arts',
#   'contact': {},
#   'location': {'address': '1540 15th Ave',
#    'crossStreet': 'btwn Pine & Madison',
#    'lat': 47.61494133816538,
#    'lng': -122.31276512045605,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.61494133816538,
#      'lng': -122.31276512045605}],
#    'distance': 1907,
#    'postalCode': '98122',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['1540 15th Ave (btwn Pine & Madison)',
#     'Seattle, WA 98122',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4d893ccf76e1236a5e480143',
#   'name': 'Seattle Bouldering Project',
#   'contact': {},
#   'location': {'address': '900 Poplar Pl S',
#    'lat': 47.59350528645206,
#    'lng': -122.31092469333515,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.59350528645206,
#      'lng': -122.31092469333515}],
#    'distance': 2479,
#    'postalCode': '98144',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['900 Poplar Pl S',
#     'Seattle, WA 98144',
#     'United States']},
#   'categories': [{'id': '503289d391d4c4b30a586d6a',
#     'name': 'Climbing Gym',
#     'pluralName': 'Climbing Gyms',
#     'shortName': 'Climbing Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '51b5d221498eead65cd90978',
#   'name': 'CorePower Yoga',
#   'contact': {},
#   'location': {'address': '501 Broadway E, Suite 1',
#    'lat': 47.623323,
#    'lng': -122.3212249,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.623323,
#      'lng': -122.3212249}],
#    'distance': 2034,
#    'postalCode': '98102',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['501 Broadway E, Suite 1',
#     'Seattle, WA 98102',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '504b8b51e4b0838e3065d860',
#   'name': 'CorePower Yoga',
#   'contact': {},
#   'location': {'address': '1455 NW Leary Way, Suite 100',
#    'crossStreet': '15th And Leary',
#    'lat': 47.663512,
#    'lng': -122.3758951,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.663512,
#      'lng': -122.3758951}],
#    'distance': 6866,
#    'postalCode': '98107',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['1455 NW Leary Way, Suite 100 (15th And Leary)',
#     'Seattle, WA 98107',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '49e4f187f964a52075631fe3',
#   'name': '8 Limbs Yoga',
#   'contact': {},
#   'location': {'address': '500 E Pike St',
#    'crossStreet': 'at Summit Ave',
#    'lat': 47.61428001441435,
#    'lng': -122.32520767707061,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.61428001441435,
#      'lng': -122.32520767707061}],
#    'distance': 1069,
#    'postalCode': '98122',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['500 E Pike St (at Summit Ave)',
#     'Seattle, WA 98122',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4fb449d4e4b0186ba35fff7c',
#   'name': 'The Grinning Yogi',
#   'contact': {},
#   'location': {'address': '345 15th Ave E',
#    'crossStreet': 'Harrison',
#    'lat': 47.621812,
#    'lng': -122.312947,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.621812,
#      'lng': -122.312947}],
#    'distance': 2314,
#    'postalCode': '98112',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['345 15th Ave E (Harrison)',
#     'Seattle, WA 98112',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4c3503d166e40f47278aca8b',
#   'name': 'Fusion Hot Yoga',
#   'contact': {},
#   'location': {'lat': 47.793150509394636,
#    'lng': -122.21705911564538,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.793150509394636,
#      'lng': -122.21705911564538}],
#    'distance': 22454,
#    'postalCode': '98021',
#    'cc': 'US',
#    'city': 'Bothell',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['Bothell, WA 98021', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4c41e93ace54e21effc80b1a',
#   'name': 'Bala Yoga',
#   'contact': {},
#   'location': {'address': '9750 NE 119th Way',
#    'lat': 47.70721954332849,
#    'lng': -122.21107537433869,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.70721954332849,
#      'lng': -122.21107537433869}],
#    'distance': 14482,
#    'postalCode': '98034',
#    'cc': 'US',
#    'city': 'Kirkland',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['9750 NE 119th Way',
#     'Kirkland, WA 98034',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4b7ad585f964a520a53f2fe3',
#   'name': 'Yogalife Queen Anne',
#   'contact': {},
#   'location': {'address': '8 Boston St',
#    'lat': 47.63842195066046,
#    'lng': -122.35657335170501,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.63842195066046,
#      'lng': -122.35657335170501}],
#    'distance': 3721,
#    'postalCode': '98109',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['8 Boston St', 'Seattle, WA 98109', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '516a1e08e4b026a6fca409f8',
#   'name': 'Shefayoga',
#   'contact': {},
#   'location': {'address': '6521 Roosevelt Way NE',
#    'lat': 47.67632298618138,
#    'lng': -122.3175088493064,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.67632298618138,
#      'lng': -122.3175088493064}],
#    'distance': 7731,
#    'postalCode': '98115',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['6521 Roosevelt Way NE',
#     'Seattle, WA 98115',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4b2c4b52f964a52066c524e3',
#   'name': 'Shakti Vinyasa Yoga',
#   'contact': {},
#   'location': {'address': '10245 Main St',
#    'crossStreet': 'at 103rd Ave NE',
#    'lat': 47.609970356856145,
#    'lng': -122.20315517091532,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.609970356856145,
#      'lng': -122.20315517091532}],
#    'distance': 9972,
#    'postalCode': '98004',
#    'cc': 'US',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['10245 Main St (at 103rd Ave NE)',
#     'Bellevue, WA 98004',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '53b6f759498e1170f313ca16',
#   'name': 'Modo Yoga',
#   'contact': {},
#   'location': {'address': '7110 Woodlawn Ave NE',
#    'lat': 47.68004963337591,
#    'lng': -122.32387268554345,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.68004963337591,
#      'lng': -122.32387268554345}],
#    'distance': 8071,
#    'postalCode': '98115',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['7110 Woodlawn Ave NE',
#     'Seattle, WA 98115',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4d5ee289d979ba7a5a64bdc7',
#   'name': 'Bindi Yoga',
#   'contact': {},
#   'location': {'address': '5903 196th St SW',
#    'lat': 47.82168162721127,
#    'lng': -122.31291225173167,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.82168162721127,
#      'lng': -122.31291225173167}],
#    'distance': 23849,
#    'postalCode': '98036',
#    'cc': 'US',
#    'city': 'Lynnwood',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['5903 196th St SW',
#     'Lynnwood, WA 98036',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4a8e2520f964a5201b1220e3',
#   'name': 'Shakti Vinyasa Yoga',
#   'contact': {},
#   'location': {'address': '2238 NW Market St',
#    'crossStreet': 'at Ballard Ave NW',
#    'lat': 47.66870210615318,
#    'lng': -122.38631591317935,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.66870210615318,
#      'lng': -122.38631591317935}],
#    'distance': 7739,
#    'postalCode': '98107',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['2238 NW Market St (at Ballard Ave NW)',
#     'Seattle, WA 98107',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4b3f85adf964a52058a825e3',
#   'name': 'Yogabliss',
#   'contact': {},
#   'location': {'address': '7803 SE 27th St #174',
#    'lat': 47.585934309976395,
#    'lng': -122.2330302886171,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.585934309976395,
#      'lng': -122.2330302886171}],
#    'distance': 8110,
#    'postalCode': '98040',
#    'cc': 'US',
#    'city': 'Mercer Island',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['7803 SE 27th St #174',
#     'Mercer Island, WA 98040',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4f358e3ae4b0c48479c4631e',
#   'name': 'ProSports Club Spa',
#   'contact': {},
#   'location': {'address': '4455 148th Ave NE',
#    'lat': 47.65126869826382,
#    'lng': -122.14475850400756,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.65126869826382,
#      'lng': -122.14475850400756}],
#    'distance': 15133,
#    'postalCode': '98007',
#    'cc': 'US',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['4455 148th Ave NE',
#     'Bellevue, WA 98007',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1ed941735',
#     'name': 'Spa',
#     'pluralName': 'Spas',
#     'shortName': 'Spa',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4f35f9e6e4b0d9574b75e5ca',
#   'name': 'Live Love Flow',
#   'contact': {},
#   'location': {'address': '1223 E Cherry St',
#    'crossStreet': 'at 12th Ave.',
#    'lat': 47.60795801031411,
#    'lng': -122.31650408008433,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.60795801031411,
#      'lng': -122.31650408008433}],
#    'distance': 1463,
#    'postalCode': '98122',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['1223 E Cherry St (at 12th Ave.)',
#     'Seattle, WA 98122',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '52f2984e11d2921a7bfedf74',
#   'name': 'CorePower Yoga',
#   'contact': {},
#   'location': {'address': '10307 NE 10th St',
#    'crossStreet': 'Bellevue Way NE',
#    'lat': 47.619095170849626,
#    'lng': -122.20276772975922,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.619095170849626,
#      'lng': -122.20276772975922}],
#    'distance': 10074,
#    'postalCode': '98004',
#    'cc': 'US',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['10307 NE 10th St (Bellevue Way NE)',
#     'Bellevue, WA 98004',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '49e39ed3f964a520a1621fe3',
#   'name': 'Sweat Box Yoga',
#   'contact': {},
#   'location': {'address': '1417 10th Ave',
#    'lat': 47.61367687598626,
#    'lng': -122.31953490052807,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.61367687598626,
#      'lng': -122.31953490052807}],
#    'distance': 1387,
#    'postalCode': '98122',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['1417 10th Ave',
#     'Seattle, WA 98122',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '88453892'},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4eada0f430f855f5b364b7c0',
#   'name': 'Get Zen Hot Yoga',
#   'contact': {},
#   'location': {'address': '13112 NE 20th St',
#    'lat': 47.628744546700574,
#    'lng': -122.1653690168888,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.628744546700574,
#      'lng': -122.1653690168888}],
#    'distance': 13010,
#    'postalCode': '98005',
#    'cc': 'US',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['13112 NE 20th St',
#     'Bellevue, WA 98005',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '552dd2dc498e0b5e98028a5c',
#   'name': 'CorePower Yoga',
#   'contact': {},
#   'location': {'address': '4535 12th Ave NE, Ste A',
#    'lat': 47.6621772,
#    'lng': -122.3156506,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.6621772,
#      'lng': -122.3156506}],
#    'distance': 6221,
#    'postalCode': '98105',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['4535 12th Ave NE, Ste A',
#     'Seattle, WA 98105',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4b945d59f964a5206f7634e3',
#   'name': 'Bikram Yoga',
#   'contact': {},
#   'location': {'address': '222 Williams Ave S',
#    'lat': 47.480291299680346,
#    'lng': -122.20636414361985,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.480291299680346,
#      'lng': -122.20636414361985}],
#    'distance': 17233,
#    'postalCode': '98057',
#    'cc': 'US',
#    'city': 'Renton',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['222 Williams Ave S',
#     'Renton, WA 98057',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4fceab6fe4b08ffd9b7acb72',
#   'name': 'Crunch - Bellevue',
#   'contact': {},
#   'location': {'address': '15600 Northeast 8th Street',
#    'lat': 47.6187131,
#    'lng': -122.1314311,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.6187131,
#      'lng': -122.1314311}],
#    'distance': 15397,
#    'postalCode': '98008',
#    'cc': 'US',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['15600 Northeast 8th Street',
#     'Bellevue, WA 98008',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d175941735',
#     'name': 'Gym / Fitness Center',
#     'pluralName': 'Gyms or Fitness Centers',
#     'shortName': 'Gym / Fitness',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '526734516'},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4aca3977f964a520f1c020e3',
#   'name': 'Bellevue Club',
#   'contact': {},
#   'location': {'address': '11200 SE 6th St',
#    'lat': 47.605763665880076,
#    'lng': -122.18938521169771,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.605763665880076,
#      'lng': -122.18938521169771}],
#    'distance': 11006,
#    'postalCode': '98004',
#    'cc': 'US',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['11200 SE 6th St',
#     'Bellevue, WA 98004',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d175941735',
#     'name': 'Gym / Fitness Center',
#     'pluralName': 'Gyms or Fitness Centers',
#     'shortName': 'Gym / Fitness',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '47150774'},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '521945ed11d244d69e56f626',
#   'name': 'CorePower Yoga',
#   'contact': {},
#   'location': {'address': '10004 Aurora Avenue North, Suite #6',
#    'lat': 47.703066996377984,
#    'lng': -122.3443791988575,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.703066996377984,
#      'lng': -122.3443791988575}],
#    'distance': 10601,
#    'postalCode': '98133',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['10004 Aurora Avenue North, Suite #6',
#     'Seattle, WA 98133',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4b15c1f6f964a520d6b323e3',
#   'name': 'Foundation CrossFit',
#   'contact': {},
#   'location': {'address': '1415 12th Ave',
#    'crossStreet': 'between Pike & Union',
#    'lat': 47.61356548262911,
#    'lng': -122.31730881933828,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.61356548262911,
#      'lng': -122.31730881933828}],
#    'distance': 1533,
#    'postalCode': '98122',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['1415 12th Ave (between Pike & Union)',
#     'Seattle, WA 98122',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '61645818'},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '5810066c38fa3355dc0952f1',
#   'name': 'TRIBE Fitness',
#   'contact': {},
#   'location': {'address': '606 Broadway E',
#    'lat': 47.624561268467666,
#    'lng': -122.32075641106029,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.624561268467666,
#      'lng': -122.32075641106029}],
#    'distance': 2169,
#    'postalCode': '98102',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['606 Broadway E',
#     'Seattle, WA 98102',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '494657837'},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4c522f647f6e20a155ea4aeb',
#   'name': 'Hot Yoga Inc.',
#   'contact': {},
#   'location': {'address': '117 106th Ave NE',
#    'lat': 47.6106120174158,
#    'lng': -122.19943084731752,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.6106120174158,
#      'lng': -122.19943084731752}],
#    'distance': 10253,
#    'postalCode': '98004',
#    'cc': 'US',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['117 106th Ave NE',
#     'Bellevue, WA 98004',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '51a96c8b7dd2ee03a4f7e812',
#   'name': 'Bikram Hot Yoga U-District',
#   'contact': {},
#   'location': {'address': '4143 University Way NE',
#    'crossStreet': "btw 42nd + 41st (Above Jimmy John's)",
#    'lat': 47.65803253386116,
#    'lng': -122.3134411889146,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.65803253386116,
#      'lng': -122.3134411889146}],
#    'distance': 5820,
#    'postalCode': '98105',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ["4143 University Way NE (btw 42nd + 41st (Above Jimmy John's))",
#     'Seattle, WA 98105',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '57724682'},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4ba6f260f964a520367939e3',
#   'name': 'Hot Yoga at Mill Creek Town Center',
#   'contact': {},
#   'location': {'address': '15217 Main St #101',
#    'lat': 47.85950313051743,
#    'lng': -122.21962024595149,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.85950313051743,
#      'lng': -122.21962024595149}],
#    'distance': 29321,
#    'postalCode': '98012',
#    'cc': 'US',
#    'city': 'Mill Creek',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['15217 Main St #101',
#     'Mill Creek, WA 98012',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4ae353a1f964a5207a9321e3',
#   'name': 'The Ashram Yoga',
#   'contact': {},
#   'location': {'address': '12637 NE 85th St',
#    'lat': 47.67905554926021,
#    'lng': -122.1702655150439,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.67905554926021,
#      'lng': -122.1702655150439}],
#    'distance': 14733,
#    'postalCode': '98033',
#    'cc': 'US',
#    'city': 'Kirkland',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['12637 NE 85th St',
#     'Kirkland, WA 98033',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '52e1de1c498e58f312c98533',
#   'name': 'CorePower Yoga',
#   'contact': {},
#   'location': {'address': '300 3rd Avenue West',
#    'crossStreet': 'Thomas',
#    'lat': 47.6210855,
#    'lng': -122.3605155,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.6210855,
#      'lng': -122.3605155}],
#    'distance': 2346,
#    'postalCode': '98119',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['300 3rd Avenue West (Thomas)',
#     'Seattle, WA 98119',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '514b545fe4b0f4e8b4e8c02e',
#   'name': 'Aditi Yoga',
#   'contact': {},
#   'location': {'address': '4206 Stone Way N',
#    'lat': 47.65839643167216,
#    'lng': -122.34208534263563,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.65839643167216,
#      'lng': -122.34208534263563}],
#    'distance': 5628,
#    'postalCode': '98103',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['4206 Stone Way N',
#     'Seattle, WA 98103',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4b7368b6f964a52011ad2de3',
#   'name': 'YMCA',
#   'contact': {},
#   'location': {'address': '13723 Puget Park Dr',
#    'lat': 47.87263993358673,
#    'lng': -122.15450302204815,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.87263993358673,
#      'lng': -122.15450302204815}],
#    'distance': 32441,
#    'postalCode': '98208',
#    'cc': 'US',
#    'city': 'Everett',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['13723 Puget Park Dr',
#     'Everett, WA 98208',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4b284b30f964a520209224e3',
#   'name': 'Denali Fitness',
#   'contact': {},
#   'location': {'address': '3130 E Madison St #104',
#    'lat': 47.62696547956247,
#    'lng': -122.29161911655228,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.62696547956247,
#      'lng': -122.29161911655228}],
#    'distance': 3943,
#    'postalCode': '98112',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['3130 E Madison St #104',
#     'Seattle, WA 98112',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4ad56058f964a520ee0221e3',
#   'name': 'Olympic Athletic Club',
#   'contact': {},
#   'location': {'address': '5301 Leary Ave NW',
#    'lat': 47.666384,
#    'lng': -122.3827919,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.666384,
#      'lng': -122.3827919}],
#    'distance': 7386,
#    'postalCode': '98107',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['5301 Leary Ave NW',
#     'Seattle, WA 98107',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4a8c22ecf964a520090d20e3',
#   'name': 'Seattle Athletic Club',
#   'contact': {},
#   'location': {'address': '2020 Western Ave',
#    'lat': 47.61062270822991,
#    'lng': -122.34404818035023,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.61062270822991,
#      'lng': -122.34404818035023}],
#    'distance': 670,
#    'postalCode': '98121',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['2020 Western Ave',
#     'Seattle, WA 98121',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '459415bbf964a52057401fe3',
#   'name': 'Samadhi Yoga',
#   'contact': {},
#   'location': {'address': '1205 E Pike St',
#    'crossStreet': 'at 12th',
#    'lat': 47.6140183985129,
#    'lng': -122.3167197854135,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.6140183985129,
#      'lng': -122.3167197854135}],
#    'distance': 1594,
#    'postalCode': '98122',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['1205 E Pike St (at 12th)',
#     'Seattle, WA 98122',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '41351100f964a520bd1a1fe3',
#   'name': 'Pro Sports Club',
#   'contact': {},
#   'location': {'address': '4455 148th Ave NE',
#    'crossStreet': 'btwn NE 45th & 46th St',
#    'lat': 47.65175455426816,
#    'lng': -122.14504565674004,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.65175455426816,
#      'lng': -122.14504565674004}],
#    'distance': 15130,
#    'postalCode': '98007',
#    'cc': 'US',
#    'city': 'Bellevue',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['4455 148th Ave NE (btwn NE 45th & 46th St)',
#     'Bellevue, WA 98007',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d176941735',
#     'name': 'Gym',
#     'pluralName': 'Gyms',
#     'shortName': 'Gym',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
# ...
#   'name': 'Village Green Yoga & Eco-Boutique',
#   'contact': {},
#   'location': {'address': '317 NW Gilman Blvd Ste 1',
#    'lat': 47.539659974252515,
#    'lng': -122.04091791268338,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.539659974252515,
#      'lng': -122.04091791268338}],
#    'distance': 23430,
#    'postalCode': '98027',
#    'cc': 'US',
#    'city': 'Issaquah',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['317 NW Gilman Blvd Ste 1',
#     'Issaquah, WA 98027',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4b7b7aa5f964a52001652fe3',
#   'name': 'Home Yoga',
#   'contact': {},
#   'location': {'address': '525 1st Ave W',
#    'lat': 47.623990193974436,
#    'lng': -122.35807615620878,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.623990193974436,
#      'lng': -122.35807615620878}],
#    'distance': 2431,
#    'postalCode': '98119',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['525 1st Ave W',
#     'Seattle, WA 98119',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '54f205da498e8baffb1f9079',
#   'name': 'Seattle Holistic Center',
#   'contact': {},
#   'location': {'address': '7700 Aurora Ave N',
#    'lat': 47.68487055889322,
#    'lng': -122.34431532117438,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.68487055889322,
#      'lng': -122.34431532117438}],
#    'distance': 8579,
#    'postalCode': '98103',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['7700 Aurora Ave N',
#     'Seattle, WA 98103',
#     'United States']},
#   'categories': [{'id': '54541900498ea6ccd0202697',
#     'name': 'Health & Beauty Service',
#     'pluralName': 'Health & Beauty Services',
#     'shortName': 'Health & Beauty',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4c194f9d98f4a593bfe5fff5',
#   'name': 'UniverseCity Yoga',
#   'contact': {},
#   'location': {'address': '4212 University Way NE Ste 202',
#    'crossStreet': '42nd',
#    'lat': 47.65862,
#    'lng': -122.312968,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.65862,
#      'lng': -122.312968}],
#    'distance': 5893,
#    'postalCode': '98105',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['4212 University Way NE Ste 202 (42nd)',
#     'Seattle, WA 98105',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4b5df3a2f964a520ac7529e3',
#   'name': 'Sutra Yoga',
#   'contact': {},
#   'location': {'address': '1621 N 45th St',
#    'lat': 47.661359857189915,
#    'lng': -122.33813236113103,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.661359857189915,
#      'lng': -122.33813236113103}],
#    'distance': 5942,
#    'postalCode': '98103',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['1621 N 45th St',
#     'Seattle, WA 98103',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4b02f2b0f964a5204c4b22e3',
#   'name': 'Community Fitness',
#   'contact': {},
#   'location': {'address': '2113 NE 65th St',
#    'crossStreet': '21st Ave NE',
#    'lat': 47.67574893482343,
#    'lng': -122.30468933284402,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.67574893482343,
#      'lng': -122.30468933284402}],
#    'distance': 7898,
#    'postalCode': '98115',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['2113 NE 65th St (21st Ave NE)',
#     'Seattle, WA 98115',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4ce1c9ba78ddf04d4d66ad98',
#   'name': 'Aum Yoga Therapy',
#   'contact': {},
#   'location': {'address': '600 1st Ave Ste 530',
#    'lat': 47.60217,
#    'lng': -122.333915,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.60217,
#      'lng': -122.333915}],
#    'distance': 667,
#    'postalCode': '98104',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['600 1st Ave Ste 530',
#     'Seattle, WA 98104',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4c7585be2db5236a5642bd79',
#   'name': 'Aspira Yoga Studio',
#   'contact': {},
#   'location': {'address': '1823 Terry Ave',
#    'lat': 47.61601394693104,
#    'lng': -122.33383182848539,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.61601394693104,
#      'lng': -122.33383182848539}],
#    'distance': 906,
#    'postalCode': '98101',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['1823 Terry Ave',
#     'Seattle, WA 98101',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '53fbe690498ed00f02d49cf0',
#   'name': 'Levitas Studio',
#   'contact': {},
#   'location': {'address': '2217 3rd Ave #103',
#    'crossStreet': '3rd and Bell',
#    'lat': 47.61427138832217,
#    'lng': -122.34407498166794,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.61427138832217,
#      'lng': -122.34407498166794}],
#    'distance': 924,
#    'postalCode': '98121',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['2217 3rd Ave #103 (3rd and Bell)',
#     'Seattle, WA 98121',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '136524872'},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '4a4ef33df964a52035af1fe3',
#   'name': 'Taj Yoga',
#   'contact': {},
#   'location': {'address': '9250 14th Ave NW Rm 2',
#    'crossStreet': 'btw NW 95th St and NW 92nd St',
#    'lat': 47.69723014555102,
#    'lng': -122.37385230959782,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.69723014555102,
#      'lng': -122.37385230959782}],
#    'distance': 10330,
#    'postalCode': '98117',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['9250 14th Ave NW Rm 2 (btw NW 95th St and NW 92nd St)',
#     'Seattle, WA 98117',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '5673604a498e9b49cd5ee778',
#   'name': 'Breathe Hot Yoga',
#   'contact': {},
#   'location': {'address': '2720 4th Ave Apt 115',
#    'crossStreet': 'Denny',
#    'lat': 47.61824529453674,
#    'lng': -122.34857083829304,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.61824529453674,
#      'lng': -122.34857083829304}],
#    'distance': 1480,
#    'postalCode': '98121',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['2720 4th Ave Apt 115 (Denny)',
#     'Seattle, WA 98121',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '54f8c753498e3524bb915313',
#   'name': "Troy Lucero's Acme Yoga Project",
#   'contact': {},
#   'location': {'address': '915 E Pine St',
#    'lat': 47.614922078531116,
#    'lng': -122.31817354968148,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.614922078531116,
#      'lng': -122.31817354968148}],
#    'distance': 1543,
#    'postalCode': '98122',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['915 E Pine St',
#     'Seattle, WA 98122',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '56f0dd2b498e339a6f973b13',
#   'name': 'Shanogi Yoga',
#   'contact': {},
#   'location': {'address': '117 E Louisa St #727',
#    'lat': 47.62178534571469,
#    'lng': -122.32757091522217,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.62178534571469,
#      'lng': -122.32757091522217}],
#    'distance': 1659,
#    'postalCode': '98102',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['117 E Louisa St #727',
#     'Seattle, WA 98102',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  {'id': '57a9551238facdd976317875',
#   'name': 'Eka Yoga',
#   'contact': {},
#   'location': {'lat': 47.625256757888806,
#    'lng': -122.34771456458174,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 47.625256757888806,
#      'lng': -122.34771456458174}],
#    'distance': 2112,
#    'postalCode': '98109',
#    'cc': 'US',
#    'city': 'Seattle',
#    'state': 'WA',
#    'country': 'United States',
#    'formattedAddress': ['Seattle, WA 98109', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d102941735',
#     'name': 'Yoga Studio',
#     'pluralName': 'Yoga Studios',
#     'shortName': 'Yoga Studio',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': False,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}}]

# %%
import pandas as pd
df = pd.DataFrame(venues).head().T

# %%
df
# Out:
#                                                             0  \
# _id                                  5cef13eee412169f21482d6b
# beenHere    {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# categories  [{'id': '4bf58dd8d48988d102941735', 'name': 'Y...
# contact                                                    {}
# hereNow     {'count': 0, 'summary': 'Nobody here', 'groups...
# id                                   4a823b1cf964a520f4f81fe3
# location    {'address': '1900 4th Ave', 'crossStreet': 'at...
# name                                           Urban Yoga Spa
# photos                             {'count': 0, 'groups': []}
# stats       {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# venuePage                                                 NaN
# verified                                                 True
#
#                                                             1  \
# _id                                  5cef13eee412169f21482d6c
# beenHere    {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# categories  [{'id': '4bf58dd8d48988d102941735', 'name': 'Y...
# contact                                                    {}
# hereNow     {'count': 0, 'summary': 'Nobody here', 'groups...
# id                                   4b08b44ef964a520161123e3
# location    {'address': '900 Lenora St Ste 128', 'crossStr...
# name                                         Be Luminous Yoga
# photos                             {'count': 0, 'groups': []}
# stats       {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# venuePage                                                 NaN
# verified                                                 True
#
#                                                             2  \
# _id                                  5cef13eee412169f21482d6d
# beenHere    {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# categories  [{'id': '4bf58dd8d48988d102941735', 'name': 'Y...
# contact                                                    {}
# hereNow     {'count': 0, 'summary': 'Nobody here', 'groups...
# id                                   4a8e262df964a5201d1220e3
# location    {'address': '2131 Queen Anne Ave N', 'crossStr...
# name                                               Haute Yoga
# photos                             {'count': 0, 'groups': []}
# stats       {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# venuePage                                                 NaN
# verified                                                False
#
#                                                             3  \
# _id                                  5cef13eee412169f21482d6e
# beenHere    {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# categories  [{'id': '4bf58dd8d48988d102941735', 'name': 'Y...
# contact                                                    {}
# hereNow     {'count': 0, 'summary': 'Nobody here', 'groups...
# id                                   4be7229a334fb7131ae8a0bc
# location    {'address': '1540 15th Ave', 'crossStreet': 'b...
# name                                        Seattle Yoga Arts
# photos                             {'count': 0, 'groups': []}
# stats       {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# venuePage                                                 NaN
# verified                                                False
#
#                                                             4
# _id                                  5cef13eee412169f21482d6f
# beenHere    {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# categories  [{'id': '503289d391d4c4b30a586d6a', 'name': 'C...
# contact                                                    {}
# hereNow     {'count': 0, 'summary': 'Nobody here', 'groups...
# id                                   4d893ccf76e1236a5e480143
# location    {'address': '900 Poplar Pl S', 'lat': 47.59350...
# name                               Seattle Bouldering Project
# photos                             {'count': 0, 'groups': []}
# stats       {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# venuePage                                                 NaN
# verified                                                 True
